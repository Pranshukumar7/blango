# %%
import pandas as pd 
df = pd.read_csv('text.csv')
print(df)
type(df)
# Out:
#           model  Root Mean Squared  Accuracy on Traing set  \
# 0           MLP         205.550645                0.689850
# 1      AdaBoost         148.177027                0.832878
# 2  DecisionTree         115.421645                0.999993
# 3  RandomForest          84.069592                0.991793
# 4    ExtraTrees          80.262533                0.999993
#
#    Accuracy on Testing set
# 0                 0.648143
# 1                 0.817152
# 2                 0.889056
# 3                 0.941142
# 4                 0.946352
# pandas.core.frame.DataFrame

# %%
df.drop(columns="Root Mean Squared" , inplace = True)

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x="model",xlabel = "Model",ylabel = "Accuracy" ,marker = "*")
# Out:
# <Axes: xlabel='Model', ylabel='Accuracy'>
